# %% [markdown]
# <a href="https://colab.research.google.com/github/alaplace17/DS1002_Alexander_Laplace/blob/main/WordsHW_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install english_words
from english_words import get_english_words_set
words = get_english_words_set(['web2'], lower=True)

type(words)
wordlist = list(words)
print("The wordlist is", len(wordlist), "words long and is the type", type(words),".")


print(f"The first ten words in the wordlist are {wordlist[0:10]}.")

alpha_list = sorted(wordlist)
print(f"The first ten words of the alphabetically sorted wordlist are {alpha_list[0:10]}.")

import numpy as np

wordlist_array = np.array(wordlist)
alpha_list_array = np.array(alpha_list)

alphabet = [chr(i) for i in range(ord('a'),ord('z')+1)]

frequency = list()
for letter in alphabet:
  count = sum(1 for word in wordlist if word[0] == letter)
  frequency.append(count)

for letter in alphabet:
    index_letter = ord(letter) - ord('a')
    count_letter = frequency[index_letter]
    print(f"The number of words startin with the letter '{letter}' is: {count_letter}")

count_with_q = sum(1 for word in wordlist if 'q' in word)
print(f"The number of words with the letter 'q' is: {count_with_q}")

count_without_e = sum(1 for word in wordlist if 'e' not in word)
print(f"The number of words without the letter 'e' is: {count_without_e}")

sorted_wordlist = sorted(wordlist, key=len, reverse=True)

six_longest_words = sorted_wordlist[:6]
print("The 6 longest words are: ")
for word in six_longest_words:
    print(word)

import matplotlib.pyplot as plt

count_letter_array = np.array(count_letter)

plt.bar(alphabet, frequency)

plt.xlabel('Alphabet Letter')
plt.ylabel('Number of Words')
plt.title('Number of Words Starting with Each Letter')

plt.ylim((0, 25000))

plt.show()

from collections import Counter

word_length_counts = Counter(len(word) for word in wordlist)

most_common_length, frequency_word_length = word_length_counts.most_common(1)[0]

print(f"The most common word length is {most_common_length} with a frequency of {frequency_word_length}.")

lengths, frequency_word_length = zip(*sorted(word_length_counts.items()))

plt.bar(lengths, frequency_word_length, width=1.0, align='edge')
plt.xlabel('Word Length')
plt.ylabel('Number of Words')
plt.title('Histogram of Word Lengths Counts')
plt.show()
# Out:
# ...
# The wordlist is 234450 words long and is the type <class 'set'> .
# The first ten words in the wordlist are ['begay', 'unfloor', 'rukbat', 'milliliter', 'rotular', 'superaxillary', 'tranquillize', 'reconstructionist', 'berm', 'orthograph'].
# The first ten words of the alphabetically sorted wordlist are ['a', 'aa', 'aal', 'aalii', 'aam', 'aani', 'aardvark', 'aardwolf', 'aaron', 'aaronic'].
# The number of words startin with the letter 'a' is: 16982
# The number of words startin with the letter 'b' is: 10970
# The number of words startin with the letter 'c' is: 19789
# The number of words startin with the letter 'd' is: 10853
# The number of words startin with the letter 'e' is: 8705
# The number of words startin with the letter 'f' is: 6841
# The number of words startin with the letter 'g' is: 6772
# The number of words startin with the letter 'h' is: 8997
# The number of words startin with the letter 'i' is: 8787
# The number of words startin with the letter 'j' is: 1604
# ...
